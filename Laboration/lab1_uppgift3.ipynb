# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import plotly_express as px

# %%
# KPI 1: Vaccinationer per åldersgrupp

vaccinerade_alder = pd.read_excel("visualiseringar\\vaccin.xlsx", sheet_name="Dos 1 till 3 per åldersgrupp")  
# veckodata_riket = pd.read_excel("visualiseringar\\covid-19.xlsx", sheet_name="Veckodata Reiket")

# %%
display(vaccinerade_alder.head())

px.bar(vaccinerade_alder, x = "Åldersgrupp", y = "Andel vaccinerade", color = "Vaccinationsstatus")
# Out:
#         Region Åldersgrupp  Antal vaccinerade  Andel vaccinerade  \
# 0  | Sverige |       12-15              22864           0.045380
# 1  | Sverige |       12-15             255541           0.507196
# 2  | Sverige |       16-17              11597           0.048013
# 3  | Sverige |       16-17             175480           0.726508
# 4  | Sverige |       18-29              56672           0.038397
#
#   Vaccinationsstatus
# 0              1 dos
# 1            2 doser
# 2              1 dos
# 3            2 doser
# 4              1 dos

# %%
plot = sns.catplot(x="Åldersgrupp", y="Andel vaccinerade", data=vaccinerade_alder, errorbar=None, col="Vaccinationsstatus", kind="bar")

for axes in plot.axes.flat:
    _ = axes.set_xticklabels(axes.get_xticklabels(), rotation=90)

plt.tight_layout()
plt.show()
# Out:
# C:\Users\yonis\AppData\Local\Temp\ipykernel_16816\2605259219.py:4: UserWarning:
#
# set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#
# C:\Users\yonis\AppData\Local\Temp\ipykernel_16816\2605259219.py:4: UserWarning:
#
# set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#
# C:\Users\yonis\AppData\Local\Temp\ipykernel_16816\2605259219.py:4: UserWarning:
#
# set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.

# %%
per_aldersgrupp = pd.read_excel("visualiseringar\\covid-19.xlsx", sheet_name="Totalt antal per åldersgrupp")  

per_aldersgrupp.head()

per_aldersgrupp["Andel avlidna"] = per_aldersgrupp["Totalt_antal_avlidna"]/per_aldersgrupp["Totalt_antal_fall"]
per_aldersgrupp["Andel intensivvårdade"] = per_aldersgrupp["Totalt_antal_intensivvårdade"]/per_aldersgrupp["Totalt_antal_fall"]

# %%
per_aldersgrupp
# Out:
#        Åldersgrupp  Totalt_antal_fall  Totalt_antal_intensivvårdade  \
# 0        Ålder_0_9             138071                           109
# 1      Ålder_10_19             355823                           101
# 2      Ålder_20_29             418506                           285
# 3      Ålder_30_39             493443                           492
# 4      Ålder_40_49             474702                           997
# 5      Ålder_50_59             378468                          1932
# 6      Ålder_60_69             180079                          2595
# 7      Ålder_70_79              87096                          2394
# 8      Ålder_80_89              58170                           612
# 9    Ålder_90_plus              26677                            21
# 10  Uppgift saknas                545                             6
#
#     Totalt_antal_avlidna  Andel avlidna  Andel intensivvårdade
# 0                     17       0.000123               0.000789
# ...

# %%
plot = sns.catplot(x="Åldersgrupp", y="Andel avlidna", data=per_aldersgrupp, errorbar = None, kind = "bar")

plot.set_xticklabels(rotation=90)

# Har inte tidsserier på vaccin och åldersgrupp, kan därför inte jämföra andel avlidna innan och efter vaccin i denna uppgift.

# %%
plot = sns.catplot(x="Åldersgrupp", y="Andel intensivvårdade", data=per_aldersgrupp, errorbar = None, kind = "bar")

plot.set_xticklabels(rotation=90)

# %%
vaccinationer_tiddserie = pd.read_excel("visualiseringar\\vaccin.xlsx", sheet_name="Vaccinationer tidsserie")

# %%
vaccinationer_tiddserie
# Out:
#       Vecka    År          Region  Antal vaccinationer
# 0        52  2020     | Sverige |                 2478
# 1        52  2020       Stockholm                  289
# 2        52  2020         Uppsala                    9
# 3        52  2020    Södermanland                  116
# 4        52  2020    Östergötland                  214
# ...     ...   ...             ...                  ...
# 2107     42  2022       Gävleborg               726017
# 2108     42  2022  Västernorrland               632660
# 2109     42  2022        Jämtland               328655
# 2110     42  2022    Västerbotten               724409
# 2111     42  2022      Norrbotten               659824
#
# [2112 rows x 4 columns]

# %%
# new_column_tidsserie = vaccinationer_tiddserie["År"].apply(str) + "v" + vaccinationer_tiddserie["Vecka"].apply(str)    # Apply här för att varje värde ska omvandlas till str
# vaccinationer_tiddserie.insert(2, "Vecka2", new_column_tidsserie)


px.bar(vaccinationer_tiddserie, x = "Vecka", y = "Antal vaccinationer")

# %%
vaccinerade_tiddserie = pd.read_excel("visualiseringar\\vaccin.xlsx", sheet_name="Vaccinerade tidsserie") 
new_column_tidsserie = vaccinerade_tiddserie["År"].apply(str) + "v" + vaccinerade_tiddserie["Vecka"].apply(str)    # Apply här för att varje värde ska omvandlas till str
vaccinerade_tiddserie.insert(2, "Vecka2", new_column_tidsserie)

# %%
px.bar(vaccinerade_tiddserie, x = "Vecka2", y = "Andel vaccinerade", color = "Vaccinationsstatus" )

# %%
# DESSA KPI:ER VILL JAG HA

# Andel avlidna per region
# Andel vaccinerade per region
# Andel 70+ per region 
# Andel fall per region.
# Ta med karta

# %%
# LÄSER IN DATA SETT FÖR ATT RÄKNA UT ANDEL AVLIDNA SENARE

avlidna_region = pd.read_excel("visualiseringar\\covid-19.xlsx", sheet_name="Totalt antal per region")  

avlidna_region.head()
# Out:
#       Region  Totalt_antal_fall  Fall_per_100000_inv  \
# 0   Blekinge              30829         19371.449951
# 1    Dalarna              75091         26098.780273
# 2    Gotland              11874         19776.671875
# 3  Gävleborg              74803         26020.503418
# 4    Halland             108822         32349.047119
#
#    Totalt_antal_intensivvårdade  Totalt_antal_avlidna
# 0                            85                   184
# 1                           260                   544
# 2                            46                    82
# 3                           332                   754
# 4                           229                   518

# %%
new_df_avlidna = avlidna_region[['Region', 'Totalt_antal_avlidna']]

# %%
# LÄSER IN VACCINDATASET FÖR ATT KUNNA FÅ UT BEFOLKNINGSMÄNGD OCH ANDEL 3 DOSER

vaccinerade = pd.read_excel("visualiseringar\\vaccin.xlsx", sheet_name="Vaccinerade kommun och ålder")
vaccinerade.head()
# vaccinerade["Ålder"].unique()
# Out:
#    Län        Län_namn  Kommun     Kommun_namn  Ålder  Befolkning  \
# 0    1  Stockholms län     114  Upplands Väsby  12-15        2422
# 1    1  Stockholms län     114  Upplands Väsby  16-17        1203
# 2    1  Stockholms län     114  Upplands Väsby  18-29        6692
# 3    1  Stockholms län     114  Upplands Väsby  30-39        7332
# 4    1  Stockholms län     114  Upplands Väsby  40-49        6946
#
#    Antal minst 1 dos  Antal minst 2 doser  Antal 3 doser  Antal 4 doser  \
# 0               1206                 1046            NaN            NaN
# 1                839                  755            NaN            NaN
# 2               4887                 4469         1959.0            NaN
# 3               5542                 5240         2878.0            NaN
# 4               5592                 5429         3719.0            NaN
#
#    Andel minst 1 dos  Andel minst 2 doser  Andel 3 doser  Andel 4 doser
# ...

# %%
# vaccinerade.groupby(["Län_namn", "Ålder"])[["Befolkning", "Andel 3 doser"]].sum()

# %%
# GROUPBY FÖR ATT FÅ FRAM EN DATAFRAME MED LÄN; SUMMA BEFOLKNING OCH ANDEL 3 DOSER

tabell = vaccinerade.groupby("Län_namn", as_index = False).agg(
    sum_befolkning = pd.NamedAgg(column = "Befolkning", aggfunc = "sum"),      
    andel_vaccinerade_3_doser = pd.NamedAgg(column = "Andel 3 doser", aggfunc = "mean"))
tabell.head()
# Out:
#          Län_namn  sum_befolkning  andel_vaccinerade_3_doser
# 0    Blekinge län          139327                   0.744903
# 1    Dalarnas län          252075                   0.743440
# 2    Gotlands län           53924                   0.778085
# 3  Gävleborgs län          252216                   0.724473
# 4    Hallands län          295663                   0.749188

# %%
# VILL LÄGGA TILL ANTAL AVLIDNA PER REGION TILL TABELL 
new_df_avlidna.head()

# new_df_avlidna.iloc[:0] = tabell["Län_namn"]    # Säkerställer att regionerna stavas lika, första kolumnen i new_df_avlidna är tom, därför kan vi skriva över den med detta som får samma stavning

# # Lägger till summa befolkning till tabell
# new_tabell = tabell.merge(new_df_avlidna, left_on="Län_namn", right_on= "Region")
# Out:
#       Region  Totalt_antal_avlidna
# 0   Blekinge                   184
# 1    Dalarna                   544
# 2    Gotland                    82
# 3  Gävleborg                   754
# 4    Halland                   518

# %%
# Lägger till total antal avlidna till tabell
# Först: Gör att värden i kolumner Region och Län_namn stavas lika

tabell["Län_namn"] = new_df_avlidna["Region"]    # Säkerställer att regionerna stavas lika, första kolumnen i new_df_avlidna är tom, därför kan vi skriva över den med detta som får samma stavning

# %%
# Lägger till antal avlidna per region till tabell nu 

new_tabell = tabell.merge(new_df_avlidna, left_on="Län_namn", right_on= "Region")

new_tabell
# Out:
#                Län_namn  sum_befolkning  andel_vaccinerade_3_doser  \
# 0              Blekinge          139327                   0.744903
# 1               Dalarna          252075                   0.743440
# 2               Gotland           53924                   0.778085
# 3             Gävleborg          252216                   0.724473
# 4               Halland          295663                   0.749188
# 5   Jämtland Härjedalen          115398                   0.723064
# 6             Jönköping          317355                   0.749698
# 7                Kalmar          216763                   0.753777
# 8             Kronoberg          175503                   0.695634
# 9            Norrbotten          220199                   0.752845
# 10                Skåne         1215047                   0.698331
# 11            Stockholm         2094721                   0.710401
# 12             Sörmland          261596                   0.726309
# ...

# %%
# Tar bort överflödiga kolumnen "Region"
new_tabell.drop("Region", axis = 1, inplace = True)

# %%
# New_tabell utan "Region"

new_tabell.head()
# Out:
#     Län_namn  sum_befolkning  andel_vaccinerade_3_doser  Totalt_antal_avlidna
# 0   Blekinge          139327                   0.744903                   184
# 1    Dalarna          252075                   0.743440                   544
# 2    Gotland           53924                   0.778085                    82
# 3  Gävleborg          252216                   0.724473                   754
# 4    Halland          295663                   0.749188                   518

# %%
# Lägger till kolumnen andel avlidna per region

new_tabell["andel_avlidna"] = new_tabell["Totalt_antal_avlidna"]/new_tabell["sum_befolkning"]

# %%
# new_tabell med ny kolumn
new_tabell.head()
# Out:
#     Län_namn  sum_befolkning  andel_vaccinerade_3_doser  Totalt_antal_avlidna  \
# 0   Blekinge          139327                   0.744903                   184
# 1    Dalarna          252075                   0.743440                   544
# 2    Gotland           53924                   0.778085                    82
# 3  Gävleborg          252216                   0.724473                   754
# 4    Halland          295663                   0.749188                   518
#
#    andel_avlidna
# 0       0.001321
# 1       0.002158
# 2       0.001521
# 3       0.002990
# 4       0.001752

# %%
# Filtering only rows with ages 70 + 

alder_above_70 = vaccinerade[vaccinerade["Ålder"].isin(["70-79", "80-89", "90 eller äldre"])]

# Renaming all rows over 70 to "70+"
alder_above_70["Ålder"] = "70+"
# Out:
# C:\Users\yonis\AppData\Local\Temp\ipykernel_16816\3510685472.py:6: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
# Grouping by region and summing population over 70 to get total population over 70 in each region
per_region_above_70 = alder_above_70.groupby("Län_namn", as_index = False).agg(   
befolkning_above_70 = pd.NamedAgg(column = "Befolkning", aggfunc = "sum"))

# %%
# Adding befolkning 70 + to new_tabell by concatenating the column with befolkning_above_70 from per_region_above_70 with new_tabell
# Works since they are ordered the same way to same regions are matched.

part_table = pd.concat([new_tabell, per_region_above_70["befolkning_above_70"]], axis = "columns")

# %%
# Adding andel above 70 to final_table

part_table["andel_above_70"] = final_table["befolkning_above_70"]/final_table["sum_befolkning"]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\yonis\Documents\GitHub\Databehandling\databehandling-YOUNIS-MOUSSAVI\Laboration\lab1_uppgift3.ipynb Cell 30 line 3
#       <a href='vscode-notebook-cell:/c%3A/Users/yonis/Documents/GitHub/Databehandling/databehandling-YOUNIS-MOUSSAVI/Laboration/lab1_uppgift3.ipynb#X41sZmlsZQ%3D%3D?line=0'>1</a> # Adding andel above 70 to final_table
# ----> <a href='vscode-notebook-cell:/c%3A/Users/yonis/Documents/GitHub/Databehandling/databehandling-YOUNIS-MOUSSAVI/Laboration/lab1_uppgift3.ipynb#X41sZmlsZQ%3D%3D?line=2'>3</a> part_table["andel_above_70"] = final_table["befolkning_above_70"]/final_table["sum_befolkning"]
#
# NameError: name 'final_table' is not defined

# %%
# Looking at final table before plotting

part_table.head()
# Out:
#     Län_namn  sum_befolkning  andel_vaccinerade_3_doser  Totalt_antal_avlidna  \
# 0   Blekinge          139327                   0.744903                   184
# 1    Dalarna          252075                   0.743440                   544
# 2    Gotland           53924                   0.778085                    82
# 3  Gävleborg          252216                   0.724473                   754
# 4    Halland          295663                   0.749188                   518
#
#    andel_avlidna  befolkning_above_70  andel_above_70
# 0       0.001321                30400        0.218192
# 1       0.002158                56631        0.224659
# 2       0.001521                12484        0.231511
# 3       0.002990                54842        0.217441
# 4       0.001752                59228        0.200323

# %%
final_table = pd.concat([part_table, avlidna_region["Totalt_antal_fall"]], axis = "columns")

# %%
# Räkna ut andel fall per region i final_table
final_table["andel_fall"] = final_table["Totalt_antal_fall"]/final_table["sum_befolkning"]

# %%
# Looking at final table before plotting

final_table.head()
# Out:
#     Län_namn  sum_befolkning  andel_vaccinerade_3_doser  Totalt_antal_avlidna  \
# 0   Blekinge          139327                   0.744903                   184
# 1    Dalarna          252075                   0.743440                   544
# 2    Gotland           53924                   0.778085                    82
# 3  Gävleborg          252216                   0.724473                   754
# 4    Halland          295663                   0.749188                   518
#
#    andel_avlidna  befolkning_above_70  Totalt_antal_fall  andel_fall
# 0       0.001321                30400              30829    0.221271
# 1       0.002158                56631              75091    0.297892
# 2       0.001521                12484              11874    0.220199
# 3       0.002990                54842              74803    0.296583
# 4       0.001752                59228             108822    0.368061

# %%
# Changing the column "Län_namn" to index instead
final_table.set_index("Län_namn", inplace = True)

# %%
final_table.head()
# Out:
#            sum_befolkning  andel_vaccinerade_3_doser  Totalt_antal_avlidna  \
# Län_namn
# Blekinge           139327                   0.744903                   184
# Dalarna            252075                   0.743440                   544
# Gotland             53924                   0.778085                    82
# Gävleborg          252216                   0.724473                   754
# Halland            295663                   0.749188                   518
#
#            andel_avlidna  befolkning_above_70  Totalt_antal_fall  andel_fall
# Län_namn
# Blekinge        0.001321                30400              30829    0.221271
# Dalarna         0.002158                56631              75091    0.297892
# Gotland         0.001521                12484              11874    0.220199
# Gävleborg       0.002990                54842              74803    0.296583
# Halland         0.001752                59228             108822    0.368061

# %%
# Correlation analysis

correlation_matrix = final_table.corr().abs()

correlation_matrix
# Out:
#                            sum_befolkning  andel_vaccinerade_3_doser  \
# sum_befolkning                   1.000000                   0.462442
# andel_vaccinerade_3_doser        0.462442                   1.000000
# Totalt_antal_avlidna             0.990267                   0.468945
# andel_avlidna                    0.289367                   0.400979
# befolkning_above_70              0.991844                   0.471464
# Totalt_antal_fall                0.997810                   0.477094
# andel_fall                       0.110286                   0.337774
#
#                            Totalt_antal_avlidna  andel_avlidna  \
# sum_befolkning                         0.990267       0.289367
# andel_vaccinerade_3_doser              0.468945       0.400979
# Totalt_antal_avlidna                   1.000000       0.363089
# andel_avlidna                          0.363089       1.000000
# befolkning_above_70                    0.968632       0.286948
# ...

# %%
# Setting correlation threshold. Anything above this is considered as highly correlated. 
# Satte absolutvärde för att kunna få ut detta, inte bry sig åt vilket håll korrelation (+/-), men enbart korrelationen

threshold = 0.85

# %%
correlation_matrix.style.map(lambda x: "font-weight: bold" if x > threshold else "")  # Han gör stylingen utan att gå in närmare på det
# Out:
# <style type="text/css">
# #T_2e82c_row0_col0, #T_2e82c_row0_col2, #T_2e82c_row0_col4, #T_2e82c_row0_col5, #T_2e82c_row1_col1, #T_2e82c_row2_col0, #T_2e82c_row2_col2, #T_2e82c_row2_col4, #T_2e82c_row2_col5, #T_2e82c_row3_col3, #T_2e82c_row4_col0, #T_2e82c_row4_col2, #T_2e82c_row4_col4, #T_2e82c_row4_col5, #T_2e82c_row5_col0, #T_2e82c_row5_col2, #T_2e82c_row5_col4, #T_2e82c_row5_col5, #T_2e82c_row6_col6 {
#   font-weight: bold;
# }
# </style>
# <table id="T_2e82c">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_2e82c_level0_col0" class="col_heading level0 col0" >sum_befolkning</th>
#       <th id="T_2e82c_level0_col1" class="col_heading level0 col1" >andel_vaccinerade_3_doser</th>
#       <th id="T_2e82c_level0_col2" class="col_heading level0 col2" >Totalt_antal_avlidna</th>
#       <th id="T_2e82c_level0_col3" class="col_heading level0 col3" >andel_avlidna</th>
# ...

# %%
# Preparation for plotting my final KPI:s with mapbox
# Reading in data set with coordinates for each region

lat = [56.1431, 61.0917,57.4684, 60.6747, 56.6743, 63.0000, 57.3708, 56.4400, 56.9251, 66.8309, 55.91, 59.3194, 59.03, 59.84972, 59.9809,  64.9035619, 62.924004, 59.781254, 58.253223, 59.2752626,  58.6411935]
long = [15.3667, 14.6664, 18.4867, 17.1444, 12.8577, 14.0000, 14.3439, 15.5400, 14.7320, 20.3991, 13.6, 18.0750, 16.39, 17.63889,13.20189, 15.990117199999986, 17.836418, 16.134008, 12.244518, 15.213410500000009,16.23851609999997]
lan = ["Blekinge", "Dalarna", "Gotland", "Gävleborg", "Halland", "Jämtland Härjedalen", "Jönköping", "Kalmar", "Kronoberg", "Norrbotten", "Skåne", "Stockholm", "Sörmland", "Uppsala", "Värmland", "Västerbotten", "Västernorrland", "Västmanland", "Västra Götaland", "Örebro", "Östergötland"]

# Creating a new dataframe with coordinates for each region
df_region_coordinates = pd.DataFrame(list(zip(lan, lat, long)), columns = ["region", "lat", "long"])

# Changing lat and long value for "Kalmar"
df_region_coordinates.loc[7, "lat"] = 57.15
df_region_coordinates.loc[7, "long"] = 16.15

# %%
final_table.head()
# Out:
#            sum_befolkning  andel_vaccinerade_3_doser  Totalt_antal_avlidna  \
# Län_namn
# Blekinge           139327                   0.744903                   184
# Dalarna            252075                   0.743440                   544
# Gotland             53924                   0.778085                    82
# Gävleborg          252216                   0.724473                   754
# Halland            295663                   0.749188                   518
#
#            andel_avlidna  befolkning_above_70  Totalt_antal_fall  andel_fall
# Län_namn
# Blekinge        0.001321                30400              30829    0.221271
# Dalarna         0.002158                56631              75091    0.297892
# Gotland         0.001521                12484              11874    0.220199
# Gävleborg       0.002990                54842              74803    0.296583
# Halland         0.001752                59228             108822    0.368061

# %%
# Merging coordinates to final table based on lan
final_table = final_table.merge(df_region_coordinates, left_index = True, right_on = "region")

final_table
# Out:
#     sum_befolkning  andel_vaccinerade_3_doser  Totalt_antal_avlidna  \
# 0           139327                   0.744903                   184
# 1           252075                   0.743440                   544
# 2            53924                   0.778085                    82
# 3           252216                   0.724473                   754
# 4           295663                   0.749188                   518
# 5           115398                   0.723064                   197
# 6           317355                   0.749698                   756
# 7           216763                   0.753777                   385
# 8           175503                   0.695634                   410
# 9           220199                   0.752845                   459
# 10         1215047                   0.698331                  2587
# 11         2094721                   0.710401                  5626
# 12          261596                   0.726309                   662
# ...

# %%
final_table.head()
# Out:
#    sum_befolkning  andel_vaccinerade_3_doser  Totalt_antal_avlidna  \
# 0          139327                   0.744903                   184
# 1          252075                   0.743440                   544
# 2           53924                   0.778085                    82
# 3          252216                   0.724473                   754
# 4          295663                   0.749188                   518
#
#    andel_avlidna  befolkning_above_70  Totalt_antal_fall  andel_fall  \
# 0       0.001321                30400              30829    0.221271
# 1       0.002158                56631              75091    0.297892
# 2       0.001521                12484              11874    0.220199
# 3       0.002990                54842              74803    0.296583
# 4       0.001752                59228             108822    0.368061
#
#       region      lat     long
# 0   Blekinge  56.1431  15.3667
# 1    Dalarna  61.0917  14.6664
# 2    Gotland  57.4684  18.4867
# ...

# %%
# Plotting with mapbox, size of circle is population over 70, color is andel avlidna
fig = px.scatter_mapbox(final_table, lat="lat", lon="long", size="andel_fall", color="andel_avlidna", height = 800, width= 700 ,hover_name = final_table.index, hover_data = ["andel_vaccinerade_3_doser", "andel_above_70"])
fig.update_layout(mapbox_style="open-street-map")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# c:\Users\yonis\Documents\GitHub\Databehandling\databehandling-YOUNIS-MOUSSAVI\Laboration\lab1_uppgift3.ipynb Cell 44 line 2
#       <a href='vscode-notebook-cell:/c%3A/Users/yonis/Documents/GitHub/Databehandling/databehandling-YOUNIS-MOUSSAVI/Laboration/lab1_uppgift3.ipynb#X61sZmlsZQ%3D%3D?line=0'>1</a> # Plotting with mapbox, size of circle is population over 70, color is andel avlidna
# ----> <a href='vscode-notebook-cell:/c%3A/Users/yonis/Documents/GitHub/Databehandling/databehandling-YOUNIS-MOUSSAVI/Laboration/lab1_uppgift3.ipynb#X61sZmlsZQ%3D%3D?line=1'>2</a> fig = px.scatter_mapbox(final_table, lat="lat", lon="long", size="andel_fall", color="andel_avlidna", height = 800, width= 700 ,hover_name = final_table.index, hover_data = ["andel_vaccinerade_3_doser", "andel_above_70"])
# ...

# %%
# Plotting with mapbox, size of circle is population over 70, color is andel avlidna
fig = px.scatter_mapbox(final_table, lat="lat", lon="long", size="andel_above_70", color="andel_avlidna", height = 800, width= 700 ,hover_name = final_table.index, hover_data = ["andel_vaccinerade_3_doser", "andel_above_70"])
fig.update_layout(mapbox_style="open-street-map")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# c:\Users\yonis\Documents\GitHub\Databehandling\databehandling-YOUNIS-MOUSSAVI\Laboration\lab1_uppgift3.ipynb Cell 45 line 2
#       <a href='vscode-notebook-cell:/c%3A/Users/yonis/Documents/GitHub/Databehandling/databehandling-YOUNIS-MOUSSAVI/Laboration/lab1_uppgift3.ipynb#X62sZmlsZQ%3D%3D?line=0'>1</a> # Plotting with mapbox, size of circle is population over 70, color is andel avlidna
# ----> <a href='vscode-notebook-cell:/c%3A/Users/yonis/Documents/GitHub/Databehandling/databehandling-YOUNIS-MOUSSAVI/Laboration/lab1_uppgift3.ipynb#X62sZmlsZQ%3D%3D?line=1'>2</a> fig = px.scatter_mapbox(final_table, lat="lat", lon="long", size="andel_above_70", color="andel_avlidna", height = 800, width= 700 ,hover_name = final_table.index, hover_data = ["andel_vaccinerade_3_doser", "andel_above_70"])
# ...

# %%
## Slutsatser:
# Självklart samband mellan antal över 70 och storlek på befolkningen, samt totalt antal avlidna
# Inga självklara samband mellan övriga KPI:er, 
# Troligtvis för att de är nära varandra och inte ändras i förhållande till varandra tillräckligt.
# I plotten ovan kan vi t.ex. se hur andel över 70 år och andel avlidna i vårt dataset inte har , samt andel vaccinerade
# en tydlig trend. Det kan bero på att det finns försumbara skillnader och behövs mer data, såsom andelen fall
# Lade till men såg inget, fanns korrelation mellan andel_fall och totala antal döda, men inte andel. 
# Korrelation mellan andel över 70 och andel döda var dubbelt så stor som andel fall och andel döda.
